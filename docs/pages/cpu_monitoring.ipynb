# %% [raw]
# ---
# title: CPU monitoring
# ---

# %%
import vscodenb # importing automatically registers the ipython magic
import multiprocess as mp

def work(cpus=mp.cpu_count()):
    def f(x):
        return sum(range(x * 100_000_000))
    with mp.Pool(cpus) as p:
        p.map(f, [1] * 2 * cpus)
# Out:
# <style>
# .widget-label,
# .widget-html,
# .widget-button,
# .widget-dropdown,
# .widget-text,
# .widget-textarea {
#     color: #CCCCCC !important;  /* Set to desired color */
#     font-size: 10px !important;      /* Font size */
#
# }
# div.widget-html-content > progress { /* Outer container */
#     height: 10px !important;
#
# }
# div.jp-OutputArea-output td.output_html { /* tqdm HTML output area */
#     height: 5px !important;
# }
# div.progress { /* Jupyter Notebook (classic) */
#     height: 5px !important;
#     min-height: 5px !important;
#     margin-top: 12px !important;
# }
# div.progress-bar { /* Inner bar */
#     height: 5px !important;
#     min-height: 5px !important;
#     line-height: 5px !important;
#     color: 'white' !important;
#     padding-bottom: 0px !important;
# }
# </style>

# %% [markdown]
# ## Magic: For cells
#
# The `%%monitor` cell magic lets you monitor CPU and memory usage as a cell runs. Just add it at the top of any cell.

# %%
# %%monitor
#
# work()

# %% [markdown]
# Use `--persist` or `-p` if you want the widget to persist after cell execution completes. This can be useful as a reminder of CPU/memory used:

# %%
# %%monitor -p
#
# work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(39%/39% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 99.8% avg">
#                             <div style="width: 99.75%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 99.8% avg">
#                             <div style="width: 99.75%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 99.8% avg">
#                             <div style="width: 99.75%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 99.8% avg">
#                             <div style="width: 99.7625%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 99.3% avg">
#                             <div style="width: 99.275%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 99.2% avg">
#                             <div style="width: 99.25%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 99.0% avg">
#                             <div style="width: 99.0125%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 98.8% avg">
#                             <div style="width: 98.775%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>

# %% [markdown]
# Increase update frequency for smoother visualization use four updates per second:

# %%
# %%monitor -p -i 0.25
#
# work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(39%/39% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 100.0% avg">
#                             <div style="width: 100.0%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 99.8% avg">
#                             <div style="width: 99.7625%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 99.8% avg">
#                             <div style="width: 99.7625%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 100.0% avg">
#                             <div style="width: 100.0%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 99.8% avg">
#                             <div style="width: 99.7625%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 98.8% avg">
#                             <div style="width: 98.75%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 98.0% avg">
#                             <div style="width: 97.9875%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 99.3% avg">
#                             <div style="width: 99.26875%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>

# %%
# %%monitor -p -c
#
# work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(38%/39% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 100.0% avg">
#                             <div style="width: 100.0%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 99.8% avg">
#                             <div style="width: 99.7625%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 99.8% avg">
#                             <div style="width: 99.75%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 100.0% avg">
#                             <div style="width: 100.0%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 99.8% avg">
#                             <div style="width: 99.7625%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 99.8% avg">
#                             <div style="width: 99.75%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 99.5% avg">
#                             <div style="width: 99.5%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 98.8% avg">
#                             <div style="width: 98.78750000000001%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#                         </div></div></div>

# %% [markdown]
# Produce summary percentages instead of gauges (overrides `-p`):

# %%
# %%monitor -s
#
# work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 12px;"><div style="margin-bottom: 8px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(38%/38% mem)</span></div><table style="border-collapse: collapse; width: 100%;"><tr style="background-color: rgba(128, 128, 128, 0.1);"><td style="padding: 4px 8px; font-weight: bold;">CPU %</td><td style="padding: 4px 8px; text-align: center;">100</td><td style="padding: 4px 8px; text-align: center;">100</td><td style="padding: 4px 8px; text-align: center;">100</td><td style="padding: 4px 8px; text-align: center;">100</td><td style="padding: 4px 8px; text-align: center;">100</td><td style="padding: 4px 8px; text-align: center;">99</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">98</td></tr></table><div style="margin-top: 6px; font-size: 11px;">Total CPU time: <span style="font-weight: normal; color: #666;">28.08 s</span></div></div></div>

# %% [markdown]
# Widget fills width of cell by default. To limit width, use -w option:

# %%
# %%monitor -p -w 100
#
# work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px; max-width: 100ch;"><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(38%/39% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 100.0% avg">
#                             <div style="width: 100.0%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 100.0% avg">
#                             <div style="width: 100.0%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 100.0% avg">
#                             <div style="width: 100.0%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 100.0% avg">
#                             <div style="width: 100.0%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 99.8% avg">
#                             <div style="width: 99.75%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 99.3% avg">
#                             <div style="width: 99.2625%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 98.5% avg">
#                             <div style="width: 98.525%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 98.5% avg">
#                             <div style="width: 98.525%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>

# %% [markdown]
# You can also override the automatic computation of CPU gauges per line:

# %%
# %%monitor -p -f 4 -w 50
#
# work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px; max-width: 50ch;"><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(39%/39% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 99.8% avg">
#                             <div style="width: 99.75%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 100.0% avg">
#                             <div style="width: 100.0%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 100.0% avg">
#                             <div style="width: 100.0%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 100.0% avg">
#                             <div style="width: 100.0%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 100.0% avg">
#                             <div style="width: 100.0%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 99.8% avg">
#                             <div style="width: 99.75%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 99.3% avg">
#                             <div style="width: 99.275%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 99.5% avg">
#                             <div style="width: 99.5%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>

# %% [markdown]
# ## Context Manager: For scripts or parts of cells
#
# The context manager gives you explicit control over monitoring.
# Perfect for Python scripts or when you want programmatic control.
#
# ### Basic Context Manager

# %%
from vscodenb import CPUMonitor

with CPUMonitor(label="Computation Phase", persist=True, color=True):
    work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">Computation Phase</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(39%/40% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 99.1% avg">
#                             <div style="width: 99.12222222222222%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 99.1% avg">
#                             <div style="width: 99.11111111111111%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 98.9% avg">
#                             <div style="width: 98.91111111111111%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 99.1% avg">
#                             <div style="width: 99.08888888888889%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 98.5% avg">
#                             <div style="width: 98.47777777777777%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 94.5% avg">
#                             <div style="width: 94.45555555555556%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 89.8% avg">
#                             <div style="width: 89.78888888888889%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 88.2% avg">
#                             <div style="width: 88.24444444444445%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#                         </div></div></div>

# %% [markdown]
# All arguments to the `monitor` magic can also be passed to `CPUMonitor`:

# %%
with CPUMonitor(summary=True, label="First computation"):
    work()

with CPUMonitor(summary=True, label="Second computation"):
    work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">First computation</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 8px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(39%/39% mem)</span></div><table style="border-collapse: collapse; width: 100%;"><tr style="background-color: rgba(128, 128, 128, 0.1);"><td style="padding: 4px 8px; font-weight: bold;">CPU %</td><td style="padding: 4px 8px; text-align: center;">99</td><td style="padding: 4px 8px; text-align: center;">99</td><td style="padding: 4px 8px; text-align: center;">99</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">95</td><td style="padding: 4px 8px; text-align: center;">89</td><td style="padding: 4px 8px; text-align: center;">88</td></tr></table><div style="margin-top: 6px; font-size: 11px;">Total CPU time: <span style="font-weight: normal; color: #666;">30.92 s</span></div></div></div>
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">Second computation</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 8px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(39%/39% mem)</span></div><table style="border-collapse: collapse; width: 100%;"><tr style="background-color: rgba(128, 128, 128, 0.1);"><td style="padding: 4px 8px; font-weight: bold;">CPU %</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">99</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">99</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">95</td><td style="padding: 4px 8px; text-align: center;">89</td><td style="padding: 4px 8px; text-align: center;">90</td></tr></table><div style="margin-top: 6px; font-size: 11px;">Total CPU time: <span style="font-weight: normal; color: #666;">31.07 s</span></div></div></div>

# %% [markdown]
# ## Decorator: For functions
#
# Wrap any function with `@monitor` to automatically monitor its execution. The decorator takes the same arguments as the magic and the context manager, but here the label defaults to the function name.

# %%
from vscodenb import monitor

@monitor
def some_function():
    work()

@monitor
def other_function():
    work()

# %% [markdown]
# That lets you track CPU usage for your code in real time:

# %%
for _ in range(3):
    some_function()
other_function()

# %%
@monitor(persist=True)
def some_function():
    work()

for _ in range(3):
    some_function()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">some_function</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(39%/39% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 98.2% avg">
#                             <div style="width: 98.22222222222223%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 98.2% avg">
#                             <div style="width: 98.22222222222223%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 98.0% avg">
#                             <div style="width: 97.96666666666667%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 98.0% avg">
#                             <div style="width: 98.0%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 98.7% avg">
#                             <div style="width: 98.66666666666667%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 95.0% avg">
#                             <div style="width: 94.98888888888888%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 89.8% avg">
#                             <div style="width: 89.75555555555555%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 89.6% avg">
#                             <div style="width: 89.55555555555556%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">some_function</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(39%/39% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 99.2% avg">
#                             <div style="width: 99.25%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 99.0% avg">
#                             <div style="width: 99.0%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 98.8% avg">
#                             <div style="width: 98.7625%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 98.8% avg">
#                             <div style="width: 98.75%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 99.8% avg">
#                             <div style="width: 99.75%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 99.2% avg">
#                             <div style="width: 99.25%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 98.0% avg">
#                             <div style="width: 97.9625%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 98.2% avg">
#                             <div style="width: 98.25%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">some_function</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(39%/39% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 97.7% avg">
#                             <div style="width: 97.73333333333333%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 97.6% avg">
#                             <div style="width: 97.6%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 97.6% avg">
#                             <div style="width: 97.61111111111111%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 97.3% avg">
#                             <div style="width: 97.28888888888889%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 98.2% avg">
#                             <div style="width: 98.22222222222223%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 95.3% avg">
#                             <div style="width: 95.33333333333333%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 88.4% avg">
#                             <div style="width: 88.44444444444444%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 88.9% avg">
#                             <div style="width: 88.86666666666666%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>

# %% [markdown]
# Or profile them using `summary=True`:

# %%
@monitor(summary=True)
def some_function():
    work()

@monitor(summary=True)
def other_function():
    work()

# %%
some_function()   
other_function()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">some_function</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 8px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(39%/39% mem)</span></div><table style="border-collapse: collapse; width: 100%;"><tr style="background-color: rgba(128, 128, 128, 0.1);"><td style="padding: 4px 8px; font-weight: bold;">CPU %</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">93</td><td style="padding: 4px 8px; text-align: center;">89</td><td style="padding: 4px 8px; text-align: center;">89</td></tr></table><div style="margin-top: 6px; font-size: 11px;">Total CPU time: <span style="font-weight: normal; color: #666;">30.58 s</span></div></div></div>
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">other_function</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 8px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(39%/39% mem)</span></div><table style="border-collapse: collapse; width: 100%;"><tr style="background-color: rgba(128, 128, 128, 0.1);"><td style="padding: 4px 8px; font-weight: bold;">CPU %</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">95</td><td style="padding: 4px 8px; text-align: center;">89</td><td style="padding: 4px 8px; text-align: center;">89</td></tr></table><div style="margin-top: 6px; font-size: 11px;">Total CPU time: <span style="font-weight: normal; color: #666;">30.84 s</span></div></div></div>
