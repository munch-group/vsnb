# %% [raw]
# ---
# title: CPU monitoring
# ---

# %%
import vsnb # importing automatically registers the ipython magic
import multiprocess as mp

def work(cpus=mp.cpu_count()):
    def f(x):
        return sum(range(x * 100_000_000))
    with mp.Pool(cpus) as p:
        p.map(f, [1] * 2 * cpus)

# %% [markdown]
# ## Magic: For cells
#
# The `%%monitor` cell magic lets you monitor CPU and memory usage as a cell runs. Just add it at the top of any cell.

# %%
# %%monitor
#
# work()

# %% [markdown]
# Use `--persist` or `-p` if you want the widget to persist after cell execution completes. This can be useful as a reminder of CPU/memory used:

# %%
# %%monitor -p
#
# work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(44%/45% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 97.1% avg">
#                             <div style="width: 97.0888888888889%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 97.2% avg">
#                             <div style="width: 97.16666666666667%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 96.7% avg">
#                             <div style="width: 96.65555555555555%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 96.4% avg">
#                             <div style="width: 96.43333333333334%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 99.6% avg">
#                             <div style="width: 99.55555555555556%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 98.7% avg">
#                             <div style="width: 98.66666666666667%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 98.2% avg">
#                             <div style="width: 98.22222222222223%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 98.2% avg">
#                             <div style="width: 98.24444444444445%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>

# %% [markdown]
# Increase update frequency for smoother visualization use four updates per second:

# %%
# %%monitor -p -i 0.25
#
# work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(38%/38% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 93.7% avg">
#                             <div style="width: 93.72777777777779%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 93.4% avg">
#                             <div style="width: 93.42777777777778%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 93.0% avg">
#                             <div style="width: 92.97777777777779%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 92.8% avg">
#                             <div style="width: 92.79444444444445%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 95.6% avg">
#                             <div style="width: 95.56666666666666%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 95.3% avg">
#                             <div style="width: 95.30555555555556%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 95.7% avg">
#                             <div style="width: 95.67777777777778%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 95.2% avg">
#                             <div style="width: 95.25%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>

# %%
# %%monitor -p -c
#
# work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(39%/39% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 94.0% avg">
#                             <div style="width: 94.0%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 93.1% avg">
#                             <div style="width: 93.11111111111111%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 94.1% avg">
#                             <div style="width: 94.11111111111111%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 92.5% avg">
#                             <div style="width: 92.45555555555556%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 93.8% avg">
#                             <div style="width: 93.77777777777777%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 94.1% avg">
#                             <div style="width: 94.11111111111111%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 93.7% avg">
#                             <div style="width: 93.6888888888889%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 93.7% avg">
#                             <div style="width: 93.6888888888889%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#                         </div></div></div>

# %% [markdown]
# Produce summary percentages instead of gauges (overrides `-p`):

# %%
# %%monitor -s
#
# work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 12px;"><div style="margin-bottom: 8px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(44%/44% mem)</span></div><table style="border-collapse: collapse; width: 100%;"><tr style="background-color: rgba(128, 128, 128, 0.1);"><td style="padding: 4px 8px; font-weight: bold;">CPU %</td><td style="padding: 4px 8px; text-align: center;">94</td><td style="padding: 4px 8px; text-align: center;">93</td><td style="padding: 4px 8px; text-align: center;">92</td><td style="padding: 4px 8px; text-align: center;">92</td><td style="padding: 4px 8px; text-align: center;">95</td><td style="padding: 4px 8px; text-align: center;">95</td><td style="padding: 4px 8px; text-align: center;">94</td><td style="padding: 4px 8px; text-align: center;">94</td></tr></table><div style="margin-top: 6px; font-size: 11px;">Total CPU time: <span style="font-weight: normal; color: #666;">30.41 s</span></div></div></div>

# %% [markdown]
# Widget fills width of cell by default. To limit width, use -w option:

# %%
# %%monitor -p -w 100
#
# work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px; max-width: 100ch;"><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(39%/39% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 93.8% avg">
#                             <div style="width: 93.78888888888889%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 93.3% avg">
#                             <div style="width: 93.25555555555556%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 92.8% avg">
#                             <div style="width: 92.76666666666667%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 93.1% avg">
#                             <div style="width: 93.12222222222222%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 95.3% avg">
#                             <div style="width: 95.33333333333333%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 95.6% avg">
#                             <div style="width: 95.55555555555556%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 95.1% avg">
#                             <div style="width: 95.11111111111111%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 94.3% avg">
#                             <div style="width: 94.33333333333333%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>

# %% [markdown]
# You can also override the automatic computation of CPU gauges per line:

# %%
# %%monitor -p -f 4 -w 50
#
# work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px; max-width: 50ch;"><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(38%/38% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 94.4% avg">
#                             <div style="width: 94.44444444444444%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 94.3% avg">
#                             <div style="width: 94.34444444444445%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 94.5% avg">
#                             <div style="width: 94.54444444444444%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 93.5% avg">
#                             <div style="width: 93.45555555555556%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 96.3% avg">
#                             <div style="width: 96.30000000000001%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 96.0% avg">
#                             <div style="width: 96.0%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 96.6% avg">
#                             <div style="width: 96.57777777777778%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 95.4% avg">
#                             <div style="width: 95.42222222222222%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>

# %% [markdown]
# ## Context Manager: For scripts or parts of cells
#
# The context manager gives you explicit control over monitoring.
# Perfect for Python scripts or when you want programmatic control.
#
# ### Basic Context Manager

# %%
from vsnb import CPUMonitor

with CPUMonitor(label="Computation Phase", persist=True, color=True):
    work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">Computation Phase</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(40%/40% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 93.5% avg">
#                             <div style="width: 93.46666666666667%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 93.5% avg">
#                             <div style="width: 93.45555555555556%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 92.9% avg">
#                             <div style="width: 92.91111111111111%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 92.9% avg">
#                             <div style="width: 92.9%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 96.7% avg">
#                             <div style="width: 96.73333333333333%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 96.7% avg">
#                             <div style="width: 96.73333333333333%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 95.7% avg">
#                             <div style="width: 95.72222222222223%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 95.9% avg">
#                             <div style="width: 95.92222222222222%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#                         </div></div></div>

# %% [markdown]
# All arguments to the `monitor` magic can also be passed to `CPUMonitor`:

# %%
with CPUMonitor(summary=True, label="First computation"):
    work()

with CPUMonitor(summary=True, label="Second computation"):
    work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">First computation</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 8px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(40%/41% mem)</span></div><table style="border-collapse: collapse; width: 100%;"><tr style="background-color: rgba(128, 128, 128, 0.1);"><td style="padding: 4px 8px; font-weight: bold;">CPU %</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">99</td></tr></table><div style="margin-top: 6px; font-size: 11px;">Total CPU time: <span style="font-weight: normal; color: #666;">31.56 s</span></div></div></div>
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">Second computation</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 8px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(40%/41% mem)</span></div><table style="border-collapse: collapse; width: 100%;"><tr style="background-color: rgba(128, 128, 128, 0.1);"><td style="padding: 4px 8px; font-weight: bold;">CPU %</td><td style="padding: 4px 8px; text-align: center;">96</td><td style="padding: 4px 8px; text-align: center;">96</td><td style="padding: 4px 8px; text-align: center;">95</td><td style="padding: 4px 8px; text-align: center;">95</td><td style="padding: 4px 8px; text-align: center;">96</td><td style="padding: 4px 8px; text-align: center;">96</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">96</td></tr></table><div style="margin-top: 6px; font-size: 11px;">Total CPU time: <span style="font-weight: normal; color: #666;">30.99 s</span></div></div></div>

# %% [markdown]
# ## Decorator: For functions
#
# Wrap any function with `@monitor` to automatically monitor its execution. The decorator takes the same arguments as the magic and the context manager, but here the label defaults to the function name.

# %%
from vsnb import monitor

@monitor
def some_function():
    work()

@monitor
def other_function():
    work()

# %% [markdown]
# That lets you track CPU usage for your code in real time:

# %%
for _ in range(3):
    some_function()
other_function()

# %%
@monitor(persist=True)
def some_function():
    work()

for _ in range(3):
    some_function()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">some_function</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(40%/40% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 95.8% avg">
#                             <div style="width: 95.82222222222222%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 95.3% avg">
#                             <div style="width: 95.33333333333333%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 95.4% avg">
#                             <div style="width: 95.42222222222223%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 94.9% avg">
#                             <div style="width: 94.88888888888889%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 98.0% avg">
#                             <div style="width: 98.0%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 98.4% avg">
#                             <div style="width: 98.44444444444444%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 98.0% avg">
#                             <div style="width: 98.04444444444444%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 98.0% avg">
#                             <div style="width: 98.04444444444444%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">some_function</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(39%/40% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 93.6% avg">
#                             <div style="width: 93.55555555555556%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 92.4% avg">
#                             <div style="width: 92.36666666666666%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 92.0% avg">
#                             <div style="width: 92.0%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 91.5% avg">
#                             <div style="width: 91.5%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 95.2% avg">
#                             <div style="width: 95.21111111111111%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 94.9% avg">
#                             <div style="width: 94.86666666666666%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 95.6% avg">
#                             <div style="width: 95.63333333333334%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 92.7% avg">
#                             <div style="width: 92.74444444444445%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">some_function</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(33%/40% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 95.1% avg">
#                             <div style="width: 95.12222222222222%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 94.7% avg">
#                             <div style="width: 94.65555555555555%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 94.4% avg">
#                             <div style="width: 94.44444444444444%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 93.9% avg">
#                             <div style="width: 93.88888888888889%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 97.2% avg">
#                             <div style="width: 97.16666666666667%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 95.6% avg">
#                             <div style="width: 95.55555555555556%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 95.9% avg">
#                             <div style="width: 95.85555555555555%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 94.7% avg">
#                             <div style="width: 94.66666666666667%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>

# %% [markdown]
# Or profile them using `summary=True`:

# %%
@monitor(summary=True)
def some_function():
    work()

@monitor(summary=True)
def other_function():
    work()

# %%
some_function()   
other_function()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">some_function</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 8px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(39%/40% mem)</span></div><table style="border-collapse: collapse; width: 100%;"><tr style="background-color: rgba(128, 128, 128, 0.1);"><td style="padding: 4px 8px; font-weight: bold;">CPU %</td><td style="padding: 4px 8px; text-align: center;">95</td><td style="padding: 4px 8px; text-align: center;">95</td><td style="padding: 4px 8px; text-align: center;">95</td><td style="padding: 4px 8px; text-align: center;">95</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">96</td></tr></table><div style="margin-top: 6px; font-size: 11px;">Total CPU time: <span style="font-weight: normal; color: #666;">31.16 s</span></div></div></div>
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">other_function</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 8px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(39%/39% mem)</span></div><table style="border-collapse: collapse; width: 100%;"><tr style="background-color: rgba(128, 128, 128, 0.1);"><td style="padding: 4px 8px; font-weight: bold;">CPU %</td><td style="padding: 4px 8px; text-align: center;">94</td><td style="padding: 4px 8px; text-align: center;">94</td><td style="padding: 4px 8px; text-align: center;">93</td><td style="padding: 4px 8px; text-align: center;">94</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">96</td><td style="padding: 4px 8px; text-align: center;">96</td><td style="padding: 4px 8px; text-align: center;">96</td></tr></table><div style="margin-top: 6px; font-size: 11px;">Total CPU time: <span style="font-weight: normal; color: #666;">30.73 s</span></div></div></div>
