# %%
import vsnb # importing automatically registers the ipython magic

# %%
# %%slurm
#
# s = "Hello from srun magic!"
# Out:
# UsageError: Cell magic `%%slurm` not found.

# %%
print(s)
# Out:
# Hello from srun magic!
